# %% [markdown]
# # ML9_Assignment

# %% [markdown]
# ### Problem Statement:
#
# Compress racoon grey scale image into 5 clusters. In the end, visualize both raw and compressed image and look for quality difference

# %%
"""
Author: Chidura Santosh
Date: 19-May-2018
Assignment: Session 27

"""
# Out:
# '\nAuthor: Chidura Santosh\nDate: 19-May-2018\nAssignment: Session 27\n\n'

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Visualize greyscale image
img = misc.face(gray=True)
plt.imshow(img, cmap=plt.cm.gray)
plt.show()

# %%
plt.imsave("grey_image.png", img)

# %%
img.shape
# Out:
# (768, 1024)

# %%
row = img.shape[0]
col = img.shape[1]

c_img = img.reshape(row * col, 1)
kmeans = KMeans(n_clusters=5)
kmeans.fit(c_img)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_
labels = labels.reshape(row, col)
plt.imshow(labels)
plt.show()

# %%
plt.imsave("compressed_image.png", labels)

# %%
plt.imshow(img, cmap=plt.cm.gray)
plt.show()

plt.imshow(labels)
plt.show()
